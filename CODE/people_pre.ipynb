# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
df=pd.read_csv("/content/drive/MyDrive/WCRC2023/데이터/전처리 중 데이터/시군별_인구_인구밀도2023.csv", encoding='euc-kr')
cf=pd.read_csv("/content/drive/MyDrive/WCRC2023/데이터/전처리 중 데이터/CCTV현황_ver3_forpeople.csv", encoding='euc-kr')

# %%
df
# Out:
#      시군별       인구  면적 (㎢)          인구밀도
# 0    수원시  1230535   121.1  10161.312960
# 1    용인시  1096060   591.2   1853.958051
# 2    성남시   933279   141.6   6590.953390
# 3    화성시   977208    53.5  18265.570090
# 4    부천시   811106   699.4   1159.716900
# 5    안산시   685269   156.5   4378.715655
# 6    평택시   615225    58.5  10516.666670
# 7    안양시   551472   458.3   1203.299149
# 8    시흥시   554127   139.9   3960.879199
# 9    김포시   507605   276.6   1835.159074
# 10   광주시   404246   431.0    937.925754
# 11   광명시   283350    38.5   7359.740260
# 12   하남시   331547    36.4   9108.434066
# 13   군포시   269222    93.0   2894.860215
# 14   오산시   238763    42.7   5591.639344
# 15   이천시   232172   461.5    503.081257
# 16   안성시   202650   553.5    366.124661
# 17   의왕시   158508    54.0   2935.333333
# 18   양평군   125520   877.8    142.993848
# 19   여주시   118038   608.3    194.045701
# 20   과천시    81528    35.9   2270.974930
# 21   고양시  1089002   268.1   4061.924655
# ...

# %%
cf
# Out:
#                       소재지지번주소         위도          경도 주소_시
# 0         경기도 김포시 감정동 254-100  37.622593  126.694730  김포시
# 1       경기도 수원시 팔달구 인계동 384-2  37.270600  127.037074  수원시
# 2       경기도 이천시 백사면 현방리 99-50  37.338198  127.490725  이천시
# 3       경기도 안성시 금광면 오흥리 392-1  36.995167  127.347282  안성시
# 4        경기도 수원시 팔달구 구천동 42-1  37.274039  127.017923  수원시
# ...                       ...        ...         ...  ...
# 9995   경기도 안산시 단원구 선부동 1081번지  37.336402  126.812713  안산시
# 9996           경기도 화성시 산척동 38  37.178720  127.112528  화성시
# 9997          경기도 화성시 영천동 734  37.204604  127.105187  화성시
# 9998  경기도 화성시 우정읍 주곡리 161-190  37.129913  126.796190  화성시
# 9999        경기도 부천시 작동 122-14  37.513840  126.812101  부천시
#
# [10000 rows x 4 columns]

# %%
# '시군별'과 '주소_시' 열을 기준으로 조인을 수행합니다.
result = pd.merge(cf, df, left_on='주소_시', right_on='시군별')

# 결과를 출력합니다.
print(result)
# Out:
#                           소재지지번주소         위도          경도 주소_시  시군별      인구  \
# 0             경기도 김포시 감정동 254-100  37.622593  126.694730  김포시  김포시  507605
# 1          경기도 김포시 월곶면 포내리 185-17  37.722550  126.528902  김포시  김포시  507605
# 2               경기도 김포시 풍무동 24-12  37.609304  126.714539  김포시  김포시  507605
# 3        경기도 김포시 감정동 680 (삼환어린이집)  37.626112  126.698681  김포시  김포시  507605
# 4     경기도 김포시 감정동 508-13 (감정초등학교)  37.623482  126.695332  김포시  김포시  507605
# ...                           ...        ...         ...  ...  ...     ...
# 9995              경기도 여주시 능현동 281  37.258353  127.653980  여주시  여주시  118038
# 9996          경기도 여주시 흥천면 계신리 554  37.372761  127.517147  여주시  여주시  118038
# 9997               경기도 여주시 상동 142  37.295633  127.646522  여주시  여주시  118038
# 9998          경기도 여주시 가남읍 심석리 504  37.204034  127.557701  여주시  여주시  118038
# 9999        경기도 여주시 점동면 청안리 112-1  37.203865  127.661196  여주시  여주시  118038
#
#       면적 (㎢)         인구밀도
# 0      276.6  1835.159074
# ...

# %%
from google.colab import files
# df4를 적절한 파일 이름으로 CSV 파일로 저장
result.to_csv('cctv_인구가중치.csv', index=False, encoding='euc-kr')
# 파일을 다운로드
files.download('cctv_인구가중치.csv')
